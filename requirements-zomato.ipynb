# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/zomato-intern/__results__.html
# /kaggle/input/zomato-intern/__notebook__.ipynb
# /kaggle/input/zomato-intern/__output__.json
# /kaggle/input/zomato-intern/custom.css
# /kaggle/input/zomato-intern/__results___files/__results___65_0.png
# /kaggle/input/zomato-intern/__results___files/__results___110_1.png
# /kaggle/input/zomato-intern/__results___files/__results___69_0.png
# /kaggle/input/zomato-intern/__results___files/__results___73_1.png
# /kaggle/input/zomato-intern/__results___files/__results___68_0.png
# /kaggle/input/zomato-intern/__results___files/__results___71_1.png
# /kaggle/input/zomato-intern/__results___files/__results___91_1.png
# /kaggle/input/zomato-intern/__results___files/__results___134_1.png
# /kaggle/input/zomato-intern/__results___files/__results___99_1.png
# /kaggle/input/zomato-intern/__results___files/__results___74_1.png
# /kaggle/input/zomato-intern/__results___files/__results___100_1.png
# /kaggle/input/zomato-intern/__results___files/__results___94_0.png
# /kaggle/input/zomato-bangalore-restaurants/zomato.csv

# %%
# !pip3 install pipreqsnb
# Out:
# Collecting pipreqsnb
#   Downloading pipreqsnb-0.2.4.tar.gz (3.7 kB)
#   Preparing metadata (setup.py) ... done
# Collecting pipreqs (from pipreqsnb)
#   Downloading pipreqs-0.4.13-py2.py3-none-any.whl (33 kB)
# Requirement already satisfied: docopt in /opt/conda/lib/python3.10/site-packages (from pipreqs->pipreqsnb) (0.6.2)
# Collecting yarg (from pipreqs->pipreqsnb)
#   Downloading yarg-0.1.9-py2.py3-none-any.whl (19 kB)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from yarg->pipreqs->pipreqsnb) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->yarg->pipreqs->pipreqsnb) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->yarg->pipreqs->pipreqsnb) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->yarg->pipreqs->pipreqsnb) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->yarg->pipreqs->pipreqsnb) (2023.11.17)
# Building wheels for collected packages: pipreqsnb
#   Building wheel for pipreqsnb (setup.py) ... done
#   Created wheel for pipreqsnb: filename=pipreqsnb-0.2.4-py3-none-any.whl size=4125 sha256=61dc4ab67bb9c3037adfa3b06b8dac7f2bd4d6f8c1f184580ee12744e64ce955
#   Stored in directory: /root/.cache/pip/wheels/c3/1b/47/ca78a979321cb4bf9e812da5157fb754712f43d094bc60bf61
# Successfully built pipreqsnb
# Installing collected packages: yarg, pipreqs, pipreqsnb
# Successfully installed pipreqs-0.4.13 pipreqsnb-0.2.4 yarg-0.1.9

# %%
# !pipreqsnb --savepath ./requirements.txt /kaggle/input/zomato-intern/__notebook__.ipynb
# Out:
# pipreqs  --savepath ./requirements.txt /kaggle/working/__temp_pipreqsnb_folder

# %%
from IPython.display import FileLink 
FileLink(r'requirements.txt')
# Out:
# /kaggle/working/requirements.txt
